# %%
import pandas as pd

# %%
data = pd.read_csv('gas_station.csv', skiprows=[0,53], delimiter = ',')

# %%
data
# Out:
#              State    1996    1997    1998    1999    2000    2001    2002  \
# 0          Alabama   6,000   5,500   5,390   5,000   4,500   4,500   5,000
# 1           Alaska     263     257     267     262     377     350     390
# 2          Arizona   4,804   1,907   1,923   1,950   2,114   2,110   2,339
# 3         Arkansas   3,280   3,220   3,313   2,984   2,831   2,652   2,652
# 4       California  14,194  14,200  11,258  11,258  11,258   9,520   9,730
# 5         Colorado   2,308   2,517   2,308   2,256   2,340   2,084   2,229
# 6      Connecticut   1,948   1,800   1,532   1,654   1,639   1,526   1,558
# 7         Delaware     478     468     500     572     406     422     405
# 8    Dist. of Col.      93     128     114     100     120     166     119
# 9          Florida   9,249   9,550   9,024   9,301   9,318   9,471   9,504
# 10         Georgia   7,936   7,466   7,356   7,765   7,104   8,015   7,928
# ...

# %%
path = '../../processed/gas_station.csv'
data.to_csv(path)
