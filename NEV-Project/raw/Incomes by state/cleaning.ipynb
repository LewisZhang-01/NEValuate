# %%
import pandas as pd

# %%
data = pd.read_csv('income.csv', skiprows=[0,1,2,3,65,66,67,68,69], delimiter = ',')

# %%
data = data.drop(data.columns[[0]], axis = 1)
data = data.fillna(0)

# %%
data.head()
# Out:
#          GeoName   1948:Q1   1948:Q2   1948:Q3   1948:Q4   1949:Q1   1949:Q2  \
# 0  United States  204641.7  210069.4  215368.6  215900.3  209582.6  208642.9
# 1        Alabama    2496.0    2595.6    2669.2    2707.1    2561.9    2516.7
# 2       Alaska *      (NA)      (NA)      (NA)      (NA)      (NA)      (NA)
# 3        Arizona     896.6     919.4     968.7     953.5     937.9     964.4
# 4       Arkansas    1452.2    1645.4    1670.4    1661.8    1604.2    1490.6
#
#     1949:Q3   1949:Q4   1950:Q1  ...     2019:Q3     2019:Q4     2020:Q1  \
# 0  208379.3  209431.3  224872.3  ...  18443581.2  18623043.4  18822075.9
# 1    2473.5    2501.7    2760.8  ...    216690.0    218325.6    220503.8
# 2      (NA)      (NA)     343.4  ...     45450.0     45628.5     45416.0
# 3     957.9     974.8    1020.5  ...    335868.4    340381.5    345632.5
# 4    1477.1    1463.4    1571.4  ...    135673.5    136778.9    137821.2
#
# ...

# %%
data = data.replace("(NA)",0)

# %%
data.head()
# Out:
#          GeoName   1948:Q1   1948:Q2   1948:Q3   1948:Q4   1949:Q1   1949:Q2  \
# 0  United States  204641.7  210069.4  215368.6  215900.3  209582.6  208642.9
# 1        Alabama    2496.0    2595.6    2669.2    2707.1    2561.9    2516.7
# 2       Alaska *         0         0         0         0         0         0
# 3        Arizona     896.6     919.4     968.7     953.5     937.9     964.4
# 4       Arkansas    1452.2    1645.4    1670.4    1661.8    1604.2    1490.6
#
#     1949:Q3   1949:Q4   1950:Q1  ...     2019:Q3     2019:Q4     2020:Q1  \
# 0  208379.3  209431.3  224872.3  ...  18443581.2  18623043.4  18822075.9
# 1    2473.5    2501.7    2760.8  ...    216690.0    218325.6    220503.8
# 2         0         0     343.4  ...     45450.0     45628.5     45416.0
# 3     957.9     974.8    1020.5  ...    335868.4    340381.5    345632.5
# 4    1477.1    1463.4    1571.4  ...    135673.5    136778.9    137821.2
#
# ...

# %%
path = '../../processed/incomes.csv'
data.to_csv(path)
