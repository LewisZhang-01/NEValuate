# %%
import pandas as pd
import matplotlib.pylab as plt
import matplotlib
import numpy as np

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
OutPut = pd.DataFrame(columns = ['Year','Save_of_gas','Save_of_EV','Save_of_PHEV','Save_of_FCV'])
OutPut
# Out:
# Empty DataFrame
# Columns: [Year, Save_of_gas, Save_of_EV, Save_of_PHEV, Save_of_FCV]
# Index: []

# %% [markdown]
# # Dataset in 2022

# %%
df_gas = pd.read_excel('2022 FE Guide for DOE-release dates before 4-16-2022-no-sales -4-16-2022public.xlsx', sheet_name = '22')
df_EV = pd.read_excel('2022 FE Guide for DOE-release dates before 4-16-2022-no-sales -4-16-2022public.xlsx', sheet_name = '22 EV')
df_PHEV = pd.read_excel('2022 FE Guide for DOE-release dates before 4-16-2022-no-sales -4-16-2022public.xlsx', sheet_name = '22 PHEV')
df_FCV = pd.read_excel('2022 FE Guide for DOE-release dates before 4-16-2022-no-sales -4-16-2022public.xlsx', sheet_name = '22 FCV')

# %%
df_gas.head()
# Out:
#    Model Year             Mfr Name                  Division       Carline  \
# 0        2022                Honda                     Acura           NSX
# 1        2022         aston martin  Aston Martin Lagonda Ltd    Vantage V8
# 2        2022  Volkswagen Group of                      Audi      R8 Coupe
# 3        2022  Volkswagen Group of                      Audi  R8 Coupe RWD
# 4        2022  Volkswagen Group of                      Audi     R8 Spyder
#
#   Verify Mfr Cd  Index (Model Type Index)  Eng Displ  # Cyl Transmission  \
# 0           HNX                       521        3.5      6  Auto(AM-S9)
# 1           ASX                         4        4.0      8     Auto(A8)
# 2           VGA                        14        5.2     10  Auto(AM-S7)
# 3           VGA                        16        5.2     10  Auto(AM-S7)
# 4           VGA                        15        5.2     10  Auto(AM-S7)
#
#    City FE (Guide) - Conventional Fuel  ...  City CO2 Rounded Adjusted  \
# ...

# %%
df_EV.head()
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0                     NaN        NaN        NaN        NaN            NaN
# 1                     NaN        NaN        NaN        NaN            NaN
# 2                     NaN        NaN        NaN        NaN            NaN
# 3  Model Type Information        NaN        NaN        NaN            NaN
# 4               Model Yr    Mfr Name   Division    Carline  Verify Mfr Cd
#
#                  Unnamed: 5 Unnamed: 6 Unnamed: 7    Unnamed: 8  \
# 0                       NaN        NaN        NaN           NaN
# 1                       NaN        NaN        NaN           NaN
# 2                       NaN        NaN        NaN           NaN
# 3                       NaN        NaN        NaN           NaN
# 4  Index (Model Type Index)  Eng Displ      # Cyl  Transmission
#
#                                           Unnamed: 9  ...  \
# 0                                                NaN  ...
# ...

# %%
df_PHEV.head()
# Out:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                             Model Type Information        NaN        NaN
# 3  Model Yr  (gold fill means release date is aft...   Mfr Name   Division
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 3     Unnamed: 4                Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN            NaN                       NaN        NaN        NaN
# 1        NaN            NaN                       NaN        NaN        NaN
# 2        NaN            NaN                       NaN        NaN        NaN
# 3    Carline  Verify Mfr Cd  Index (Model Type Index)  Eng Displ      # Cyl
# 4        NaN            NaN                       NaN        NaN        NaN
#
# ...

# %%
df_FCV.head()
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0                     NaN        NaN        NaN        NaN            NaN
# 1  Model Type Information        NaN        NaN        NaN            NaN
# 2               Model Yr    Mfr Name   Division    Carline  Verify Mfr Cd
# 3                     NaN        NaN        NaN        NaN            NaN
# 4                     NaN        NaN        NaN        NaN            NaN
#
#                  Unnamed: 5 Unnamed: 6 Unnamed: 7    Unnamed: 8  \
# 0                       NaN        NaN        NaN           NaN
# 1                       NaN        NaN        NaN           NaN
# 2  Index (Model Type Index)  Eng Displ      # Cyl  Transmission
# 3                       NaN        NaN        NaN           NaN
# 4                       NaN        NaN        NaN           NaN
#
#                                           Unnamed: 9  ...  \
# 0                                                NaN  ...
# ...

# %%
df_EV['Unnamed: 150']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                     You Save/You Spend
# 4      $ You Save over 5 years (amount saved in fuel ...
#                              ...
# 249                                                  NaN
# 250                                                  NaN
# 251                                                  NaN
# 252                                                  NaN
# 253                                                  NaN
# Name: Unnamed: 150, Length: 254, dtype: object

# %%
df_FCV['Unnamed: 150']
# Out:
# 0                                                   NaN
# 1                                    You Save/You Spend
# 2     $ You Save over 5 years (amount saved in fuel ...
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  750
# 13                                                  750
# 14                                                  NaN
# 15                                                    0
# 16                                                    0
# ...

# %%
df_PHEV['Unnamed: 150']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                     You Save/You Spend
# 3      $ You Save over 5 years (amount saved in fuel ...
# 4                                                    NaN
#                              ...
# 138                                                  NaN
# 139                                                  NaN
# 140                                                  NaN
# 141                                                  NaN
# 142                                                  NaN
# Name: Unnamed: 150, Length: 143, dtype: object

# %%
df_EV = df_EV.drop(df_EV.index[[3,4]])

# %%
df_PHEV = df_PHEV.drop(df_PHEV.index[[2,3]])

# %%
df_FCV = df_FCV.drop(df_FCV.index[[1,2]])

# %%
Save_of_gas = df_gas['$ You Save over 5 years (amount saved in fuel costs over 5 years - on label) '].dropna().mean()
Save_of_EV = df_EV['Unnamed: 150'].dropna().mean()
Save_of_PHEV = df_PHEV['Unnamed: 150'].dropna().mean()
Save_of_FCV = df_FCV['Unnamed: 150'].dropna().mean()

# %%
Save_of_gas, Save_of_EV, Save_of_PHEV, Save_of_FCV
# Out:
# (1065.7894736842106, 3134.375, 1437.5, 500.0)

# %%
OutPut
# Out:
# Empty DataFrame
# Columns: [Year, Save_of_gas, Save_of_EV, Save_of_PHEV, Save_of_FCV]
# Index: []

# %%
OutPut = OutPut.append({'Year':2022, 'Save_of_gas':Save_of_gas, 'Save_of_EV':Save_of_EV, 'Save_of_PHEV':Save_of_PHEV, 'Save_of_FCV':Save_of_FCV}, ignore_index=True)
OutPut
# Out:
#      Year  Save_of_gas  Save_of_EV  Save_of_PHEV  Save_of_FCV
# 0  2022.0  1065.789474    3134.375        1437.5        500.0

# %% [markdown]
# # Dataset in 2021

# %%
df_gas = pd.read_excel('2021 FE Guide-release dates before 11-23-2021-no-sales -11-22-2021 for DOE_Karmapublic.xlsx', sheet_name = '21')
df_EV = pd.read_excel('2021 FE Guide-release dates before 11-23-2021-no-sales -11-22-2021 for DOE_Karmapublic.xlsx', sheet_name = '21 EV')
df_PHEV = pd.read_excel('2021 FE Guide-release dates before 11-23-2021-no-sales -11-22-2021 for DOE_Karmapublic.xlsx', sheet_name = '21 PHEV')
df_FCV = pd.read_excel('2021 FE Guide-release dates before 11-23-2021-no-sales -11-22-2021 for DOE_Karmapublic.xlsx', sheet_name = '21 FCV')

# %%
df_EV['Unnamed: 150']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                     You Save/You Spend
# 3      $ You Save over 5 years (amount saved in fuel ...
# 4                                                    NaN
#                              ...
# 156                                                 3250
# 157                                                 3250
# 158                                                  NaN
# 159                                                  NaN
# 160                                                  NaN
# Name: Unnamed: 150, Length: 161, dtype: object

# %%
df_PHEV['Unnamed: 150']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                     You Save/You Spend
# 4      $ You Save over 5 years (amount saved in fuel ...
#                              ...
# 165                                                  NaN
# 166                                                  NaN
# 167                                                  NaN
# 168                                                  NaN
# 169                                                  NaN
# Name: Unnamed: 150, Length: 170, dtype: object

# %%
df_FCV['Unnamed: 150']
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                    You Save/You Spend
# 3     $ You Save over 5 years (amount saved in fuel ...
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                  1250
# 8                                                  1250
# 9                                                   NaN
# 10                                                  NaN
# 11                                                    0
# 12                                                    0
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  500
# 16                                                  500
# ...

# %%
    df_EV = df_EV.drop(df_EV.index[[2,3]])
    df_PHEV = df_PHEV.drop(df_PHEV.index[[3,4]])
    df_FCV = df_FCV.drop(df_FCV.index[[2,3]])
    Save_of_gas = df_gas['$ You Save over 5 years (amount saved in fuel costs over 5 years - on label) '].dropna().mean()
    Save_of_EV = df_EV['Unnamed: 150'].dropna().mean()
    Save_of_PHEV = df_PHEV['Unnamed: 150'].dropna().mean()
    Save_of_FCV = df_FCV['Unnamed: 150'].dropna().mean()
    OutPut = OutPut.append({'Year':2021, 'Save_of_gas':Save_of_gas, 'Save_of_EV':Save_of_EV, 'Save_of_PHEV':Save_of_PHEV, 'Save_of_FCV':Save_of_FCV}, ignore_index=True)

# %%
OutPut
# Out:
#      Year  Save_of_gas   Save_of_EV  Save_of_PHEV  Save_of_FCV
# 0  2022.0  1065.789474  3134.375000   1437.500000        500.0
# 1  2021.0  1169.191919  4024.509804   1971.153846        900.0

# %% [markdown]
# # Dataset in 2020

# %%
df_gas = pd.read_excel('2020 FE Guide-adds and corrections for DOE-OK for release-no-sales- 4-7-2021Koenigseggpublic.xlsx', sheet_name = '20')
df_EV = pd.read_excel('2020 FE Guide-adds and corrections for DOE-OK for release-no-sales- 4-7-2021Koenigseggpublic.xlsx', sheet_name = '20 EV')
df_PHEV = pd.read_excel('2020 FE Guide-adds and corrections for DOE-OK for release-no-sales- 4-7-2021Koenigseggpublic.xlsx', sheet_name = '20 PHEV')
df_FCV = pd.read_excel('2020 FE Guide-adds and corrections for DOE-OK for release-no-sales- 4-7-2021Koenigseggpublic.xlsx', sheet_name = '20 FCV')

# %%
df_EV['Unnamed: 150']
# Out:
# 0                                                    NaN
# 1                                     You Save/You Spend
# 2      $ You Save over 5 years (amount saved in fuel ...
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 113                                                 4750
# 114                                                 4750
# 115                                                  NaN
# 116                                                 4500
# 117                                                 4500
# Name: Unnamed: 150, Length: 118, dtype: object

# %%
df_PHEV['Unnamed: 150'].head(10)
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                   You Save/You Spend
# 5    $ You Save over 5 years (amount saved in fuel ...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# Name: Unnamed: 150, dtype: object

# %%
df_FCV['Unnamed: 150']
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                    You Save/You Spend
# 4     $ You Save over 5 years (amount saved in fuel ...
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                  1250
# 9                                                  1250
# 10                                                  NaN
# 11                                                    0
# 12                                                    0
# 13                                                  NaN
# 14                                                  500
# 15                                                  500
# 16                                                  NaN
# ...

# %%
    df_EV = df_EV.drop(df_EV.index[[1,2]])
    df_PHEV = df_PHEV.drop(df_PHEV.index[[4,5]])
    df_FCV = df_FCV.drop(df_FCV.index[[3,4]])
    Save_of_gas = df_gas['$ You Save over 5 years (amount saved in fuel costs over 5 years - on label) '].dropna().mean()
    Save_of_EV = df_EV['Unnamed: 150'].dropna().mean()
    Save_of_PHEV = df_PHEV['Unnamed: 150'].dropna().mean()
    Save_of_FCV = df_FCV['Unnamed: 150'].dropna().mean()
    OutPut = OutPut.append({'Year':2020, 'Save_of_gas':Save_of_gas, 'Save_of_EV':Save_of_EV, 'Save_of_PHEV':Save_of_PHEV, 'Save_of_FCV':Save_of_FCV}, ignore_index=True)

# %%
OutPut
# Out:
#      Year  Save_of_gas   Save_of_EV  Save_of_PHEV  Save_of_FCV
# 0  2022.0  1065.789474  3134.375000   1437.500000        500.0
# 1  2021.0  1169.191919  4024.509804   1971.153846        900.0
# 2  2020.0  1159.793814  4269.736842   1972.222222        750.0

# %% [markdown]
# # Dataset in 2019

# %%
df_gas = pd.read_excel('2019 FE Guide-for DOE-release dates before 12-19-2019-no-sales- 12_17_2019Koenigseggpublic.xlsx', sheet_name = '2019 FEguide')
df_EV = pd.read_excel('2019 FE Guide-for DOE-release dates before 12-19-2019-no-sales- 12_17_2019Koenigseggpublic.xlsx', sheet_name = 'EVs')
df_PHEV = pd.read_excel('2019 FE Guide-for DOE-release dates before 12-19-2019-no-sales- 12_17_2019Koenigseggpublic.xlsx', sheet_name = 'PHEVs')
df_FCV = pd.read_excel('2019 FE Guide-for DOE-release dates before 12-19-2019-no-sales- 12_17_2019Koenigseggpublic.xlsx', sheet_name = 'FCVs')

# %%
df_EV['Unnamed: 150'].head(8)
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                   You Save/You Spend
# 3    $ You Save over 5 years (amount saved in fuel ...
# 4                                                  NaN
# 5                                                  NaN
# 6                                                 2500
# 7                                                 2500
# Name: Unnamed: 150, dtype: object

# %%
df_PHEV['Unnamed: 150'].head(8)
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                   You Save/You Spend
# 5    $ You Save over 5 years (amount saved in fuel ...
# 6                                                  NaN
# 7                                                  NaN
# Name: Unnamed: 150, dtype: object

# %%
df_FCV['Unnamed: 150']
# Out:
# 0                                                   NaN
# 1                                    You Save/You Spend
# 2     $ You Save over 5 years (amount saved in fuel ...
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   750
# 6                                                   750
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                    0
# 12                                                    0
# 13                                                  NaN
# 14                                                  750
# 15                                                  750
# 16                                                  NaN
# ...

# %%
    df_EV = df_EV.drop(df_EV.index[[2,3]])
    df_PHEV = df_PHEV.drop(df_PHEV.index[[4,5]])
    df_FCV = df_FCV.drop(df_FCV.index[[1,2]])
    Save_of_gas = df_gas['$ You Save over 5 years (amount saved in fuel costs over 5 years - on label) '].dropna().mean()
    Save_of_EV = df_EV['Unnamed: 150'].dropna().mean()
    Save_of_PHEV = df_PHEV['Unnamed: 150'].dropna().mean()
    Save_of_FCV = df_FCV['Unnamed: 150'].dropna().mean()
    OutPut = OutPut.append({'Year':2019, 'Save_of_gas':Save_of_gas, 'Save_of_EV':Save_of_EV, 'Save_of_PHEV':Save_of_PHEV, 'Save_of_FCV':Save_of_FCV}, ignore_index=True)

# %%
OutPut
# Out:
#      Year  Save_of_gas   Save_of_EV  Save_of_PHEV  Save_of_FCV
# 0  2022.0  1065.789474  3134.375000   1437.500000        500.0
# 1  2021.0  1169.191919  4024.509804   1971.153846        900.0
# 2  2020.0  1159.793814  4269.736842   1972.222222        750.0
# 3  2019.0   947.867299  3857.142857   2337.500000        500.0

# %% [markdown]
# # Dataset in 2018

# %%
df_gas = pd.read_excel('2018 FE Guide for DOE3 -all rel dates-no-sales-3-25-2019McLarenforpublic.xlsx', sheet_name = 'FEguide')
df_EV = pd.read_excel('2018 FE Guide for DOE3 -all rel dates-no-sales-3-25-2019McLarenforpublic.xlsx', sheet_name = 'EVs')
df_PHEV = pd.read_excel('2018 FE Guide for DOE3 -all rel dates-no-sales-3-25-2019McLarenforpublic.xlsx', sheet_name = 'PHEVs')
df_FCV = pd.read_excel('2018 FE Guide for DOE3 -all rel dates-no-sales-3-25-2019McLarenforpublic.xlsx', sheet_name = 'FCVs')

# %%
df_EV['Unnamed: 150'].head(10)
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                   You Save/You Spend
# 5    $ You Save over 5 years (amount saved in fuel ...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                 4000
# 9                                                 4000
# Name: Unnamed: 150, dtype: object

# %%
df_PHEV['Unnamed: 150'].head(10)
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                   You Save/You Spend
# 5    $ You Save over 5 years (amount saved in fuel ...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                 1750
# 9                                                 1750
# Name: Unnamed: 150, dtype: object

# %%
df_FCV['Unnamed: 150'].head(10)
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                   You Save/You Spend
# 5    $ You Save over 5 years (amount saved in fuel ...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  500
# 9                                                  500
# Name: Unnamed: 150, dtype: object

# %%
    df_EV = df_EV.drop(df_EV.index[[4,5]])
    df_PHEV = df_PHEV.drop(df_PHEV.index[[4,5]])
    df_FCV = df_FCV.drop(df_FCV.index[[4,5]])
    Save_of_gas = df_gas['$ You Save over 5 years (amount saved in fuel costs over 5 years - on label) '].dropna().mean()
    Save_of_EV = df_EV['Unnamed: 150'].dropna().mean()
    Save_of_PHEV = df_PHEV['Unnamed: 150'].dropna().mean()
    Save_of_FCV = df_FCV['Unnamed: 150'].dropna().mean()
    OutPut = OutPut.append({'Year':2018, 'Save_of_gas':Save_of_gas, 'Save_of_EV':Save_of_EV, 'Save_of_PHEV':Save_of_PHEV, 'Save_of_FCV':Save_of_FCV}, ignore_index=True)

# %%
OutPut
# Out:
#      Year  Save_of_gas   Save_of_EV  Save_of_PHEV  Save_of_FCV
# 0  2022.0  1065.789474  3134.375000   1437.500000        500.0
# 1  2021.0  1169.191919  4024.509804   1971.153846        900.0
# 2  2020.0  1159.793814  4269.736842   1972.222222        750.0
# 3  2019.0   947.867299  3857.142857   2337.500000        500.0
# 4  2018.0   920.704846  3656.250000   1815.217391        500.0

# %%
OutPut['Avg_NE'] = OutPut.iloc[:, 2:5].mean(axis=1)

# %%
OutPut
# Out:
#      Year  Save_of_gas   Save_of_EV  Save_of_PHEV  Save_of_FCV       Avg_NE
# 0  2022.0  1065.789474  3134.375000   1437.500000        500.0  1690.625000
# 1  2021.0  1169.191919  4024.509804   1971.153846        900.0  2298.554550
# 2  2020.0  1159.793814  4269.736842   1972.222222        750.0  2330.653021
# 3  2019.0   947.867299  3857.142857   2337.500000        500.0  2231.547619
# 4  2018.0   920.704846  3656.250000   1815.217391        500.0  1990.489130

# %% [markdown]
# # OUTPUT

# %%
path = '../Processed_Data/Save_money.csv'
OutPut.to_csv(path)
