# %% [markdown]
# # Load and Clean Vehicle Dataset

# %%
import json
import pandas as pd
import numpy as np
import itertools

from loguru import logger
from IPython.display import display, clear_output

# %% [markdown]
# Path to dataset

# %%
dataset = "../Raw_Data/Vehicle_Dataset.csv"
df = pd.read_csv(dataset)
df.shape
# Out:
# (335562, 9)

# %%
df
# Out:
#        Genmodel_ID   Maker    Genmodel  \
# 0              2_1  Abarth  124 spider
# 1              2_1  Abarth  124 spider
# 2              2_1  Abarth  124 spider
# 3              2_1  Abarth  124 spider
# 4              2_1  Abarth  124 spider
# ...            ...     ...         ...
# 335557       96_20   Volvo        Xc40
# 335558       96_20   Volvo        Xc40
# 335559       96_20   Volvo        Xc40
# 335560       96_20   Volvo        Xc40
# 335561       96_20   Volvo        Xc40
#
#                                                      Trim  Year  Price  \
# 0                   124 Spider1.4 Turbo MultiAir 170hp 2d  2016  29365
# 1       124 Spider1.4 Turbo MultiAir 170hp Sequenziale...  2016  31365
# 2                   124 Spider1.4 Turbo MultiAir 170hp 2d  2017  29365
# 3       124 Spider1.4 Turbo MultiAir 170hp Sequenziale...  2017  31365
# 4         124 SpiderScorpione 1.4 Turbo MultiAir 170hp 2d  2017  26665
# ...                                                   ...   ...    ...
# 335557                XC40 SUVR-Design Pro T4 AWD auto 5d  2018  35250
# 335558                XC40 SUVR-Design Pro T5 AWD auto 5d  2018  36750
# 335559                         XC40 SUVR-Design T3 FWD 5d  2018  29200
# 335560                    XC40 SUVR-Design T4 AWD auto 5d  2018  33350
# 335561                    XC40 SUVR-Design T5 AWD auto 5d  2018  34850
#
#         Gas_emission Fuel_type  Engine_size
# 0                148    Petrol         1368
# 1                153    Petrol         1368
# 2                148    Petrol         1368
# 3                153    Petrol         1368
# 4                148    Petrol         1368
# ...              ...       ...          ...
# 335557           163    Petrol         1969
# 335558           166    Petrol         1969
# 335559           144    Petrol         1477
# 335560           161    Petrol         1969
# 335561           164    Petrol         1969
#
# [335562 rows x 9 columns]

# %%
df["Fuel_type"].value_counts()
# Out:
# Petrol                 179599
# Diesel                 147860
# Other                    8085
# Electric Diesel REX        18
# Name: Fuel_type, dtype: int64

# %%
df = df.drop(['Genmodel_ID','Trim'],axis=1)

# %%
df
# Out:
#          Maker    Genmodel  Year  Price  Gas_emission Fuel_type  Engine_size
# 0       Abarth  124 spider  2016  29365           148    Petrol         1368
# 1       Abarth  124 spider  2016  31365           153    Petrol         1368
# 2       Abarth  124 spider  2017  29365           148    Petrol         1368
# 3       Abarth  124 spider  2017  31365           153    Petrol         1368
# 4       Abarth  124 spider  2017  26665           148    Petrol         1368
# ...        ...         ...   ...    ...           ...       ...          ...
# 335557   Volvo        Xc40  2018  35250           163    Petrol         1969
# 335558   Volvo        Xc40  2018  36750           166    Petrol         1969
# 335559   Volvo        Xc40  2018  29200           144    Petrol         1477
# 335560   Volvo        Xc40  2018  33350           161    Petrol         1969
# 335561   Volvo        Xc40  2018  34850           164    Petrol         1969
#
# [335562 rows x 7 columns]

# %%
#Now we have cleanned data, save it into processed directory.
path = '../Processed_Data/Vehicle_Dataset.csv'
df.to_csv(path)
